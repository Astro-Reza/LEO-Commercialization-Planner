# %% [markdown]
# bismillah
#
# stop ketika udah kena jangkauan, limit sampe 5 aja

# %%
import numpy as np
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib.animation import FuncAnimation
from skyfield.api import EarthSatellite, load, wgs84
from datetime import datetime, timedelta, timezone
from shapely.geometry import Polygon, Point # Tambah Point
from shapely.ops import unary_union
from pyproj import Geod
import csv, os

# ---------- TLE ISS (ZARYA) ----------
tle_lines = [
    "EXPLORER 22",
    "1 00899U 64064A   25276.49600160  .00000579  00000-0  49569-3 0  9991",
    "2 00899  79.6909  47.8810 0120383 146.1380 214.7533 13.82947257 69497"
]
# -------------------------------------

update_interval_ms = 200     # ms per frame
speedup = 127                # percepatan waktu simulasi
spotbeam_width_km = 2000     # lebar strip coverage tegak lurus lintasan (km)

# Inisialisasi skyfield
ts = load.timescale()
sat = EarthSatellite(tle_lines[1], tle_lines[2], tle_lines[0], ts)

# Geod untuk hitung area di ellipsoid WGS84
geod = Geod(ellps="WGS84")

# === Variabel CSV & Kontrol Penghentian ===
csv_filename = "spotbeam_data.csv"
save_counter = 0
max_saves = 5 # Batas maksimum baris CSV
stop_simulation = False # Variabel kontrol penghentian utama

# buat file baru jika belum ada
if not os.path.exists(csv_filename):
    with open(csv_filename, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["UTC_time", "Latitude", "Longitude", "Altitude_km", "Spotbeam_Area_km2"])

def latlon_at_time(time_ts):
    geocentric = sat.at(time_ts)
    subpoint = wgs84.subpoint(geocentric)
    return subpoint.latitude.degrees, subpoint.longitude.degrees, subpoint.elevation.km

# Setup figure
fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_global()
ax.stock_img()
ax.coastlines(linewidth=0.6)

# Inisialisasi plot
line_artist, = ax.plot([], [], color='red', linewidth=2, label='Lintasan Satelit', transform=ccrs.Geodetic())
point_artist, = ax.plot([], [], 'bo', markersize=6, label='Satelit', transform=ccrs.Geodetic(), zorder=5)
spotbeam_artist, = ax.plot([], [], color='blue', alpha=0.3, transform=ccrs.Geodetic(), label="Spotbeam Strip")

time_text = ax.text(0.01, 0.03, '', transform=ax.transAxes, fontsize=9,
                    bbox=dict(facecolor='white', alpha=0.7))

area_text = ax.text(0.01, 0.08, '', transform=ax.transAxes, fontsize=9,
                    bbox=dict(facecolor='white', alpha=0.7))

plt.title('Animasi Satelit dengan Spotbeam Strip (Ground Track)')
plt.legend(loc='upper right')

# Variabel penyimpan lintasan
track_lats = []
track_lons = []

# Variabel kontrol crossing orbit
start_real_time = datetime.utcnow().replace(tzinfo=timezone.utc)
start_sim_time = start_real_time
first_lat, first_lon = None, None # Titik awal simulasi
start_point = None # Titik awal sebagai objek Shapely
last_cross_state = False
cross_tolerance = 5.0

# Variabel untuk luas area cakupan
spotbeam_union = None
last_area_km2 = 0.0

def update(frame):
    global track_lats, track_lons, first_lat, first_lon, start_point, last_cross_state
    global spotbeam_union, last_area_km2, save_counter, stop_simulation

    # 🛑 MEKANISME PENGHENTIAN
    if stop_simulation:
        # Hentikan proses update frame jika kondisi penghentian terpenuhi
        return (point_artist, line_artist, spotbeam_artist, time_text, area_text)

    elapsed_real = frame * (update_interval_ms / 1000.0)
    sim_seconds = elapsed_real * speedup
    sim_time = start_sim_time + timedelta(seconds=sim_seconds)
    t_ts = ts.utc(sim_time.year, sim_time.month, sim_time.day,
                  sim_time.hour, sim_time.minute, sim_time.second + sim_time.microsecond/1e6)

    lat, lon, alt = latlon_at_time(t_ts)

    # Normalisasi longitude ke -180..180
    if lon > 180:
        lon -= 360
    elif lon < -180:
        lon += 360

    # Simpan dan definisikan titik awal hanya sekali
    if first_lat is None and first_lon is None:
        first_lat, first_lon = lat, lon
        start_point = Point(first_lon, first_lat) # Definisikan titik awal Shapely

    # ... (Logika deteksi crossing dan pembersihan lintasan tetap sama) ...
    dist = np.sqrt((lat - first_lat)**2 + (lon - first_lon)**2)
    is_crossing = dist < cross_tolerance
    if is_crossing and not last_cross_state:
        # Logika ini untuk membersihkan lintasan visual, bukan penghenti CSV utama lagi
        track_lats, track_lons = [], []
        # first_lat, first_lon = lat, lon # TIDAK di-reset agar start_point tetap sama
    last_cross_state = is_crossing

    # Tambahkan ke lintasan
    track_lats.append(lat)
    track_lons.append(lon)

    # Update titik & garis lintasan
    point_artist.set_data([lon], [lat])
    line_artist.set_data(track_lons, track_lats)

    # Hitung strip coverage
    if len(track_lats) > 1:
        lon_prev = track_lons[-2]
        lat_prev = track_lats[-2]
        dx, dy = lon - lon_prev, lat - lat_prev
        length = np.hypot(dx, dy)
        if length > 0:
            dx, dy = dx/length, dy/length
            nx, ny = -dy, dx
            half_w = (spotbeam_width_km / 111.0) / 2
            current_strip = Polygon([
                (lon_prev + nx*half_w, lat_prev + ny*half_w),
                (lon_prev - nx*half_w, lat_prev - ny*half_w),
                (lon      - nx*half_w, lat      - ny*half_w),
                (lon      + nx*half_w, lat      + ny*half_w)
            ])
            
            if spotbeam_union is None:
                spotbeam_union = current_strip
            else:
                # Akumulasi area cakupan
                spotbeam_union = unary_union([spotbeam_union, current_strip])
            
            x, y = current_strip.exterior.xy
            spotbeam_artist.set_data(x, y)

            if spotbeam_union.is_valid and not spotbeam_union.is_empty:
                polys = [spotbeam_union] if spotbeam_union.geom_type == "Polygon" else list(spotbeam_union.geoms)
                total_area_m2 = 0
                for poly in polys:
                    if len(poly.exterior.coords) >= 4:
                        poly_x, poly_y = poly.exterior.xy
                        area_m2, _ = geod.polygon_area_perimeter(poly_x, poly_y)
                        total_area_m2 += abs(area_m2)
                last_area_km2 = total_area_m2 / 1e6
                
                # 🎯 PENGHENTIAN BARU: Cek apakah titik awal sudah tercakup
                if start_point is not None and spotbeam_union.contains(start_point):
                    if save_counter < max_saves:
                        # Simpan baris terakhir sebelum berhenti
                        with open(csv_filename, "a", newline="") as f:
                            writer = csv.writer(f)
                            writer.writerow([
                                sim_time.strftime('%Y-%m-%d %H:%M:%S'),
                                f"{lat:.6f}", f"{lon:.6f}", f"{alt:.2f}", f"{last_area_km2:.2f}"
                            ])
                        save_counter += 1
                        print(f"\n[INFO] Titik awal (lat={first_lat:.2f}, lon={first_lon:.2f}) TERCATAT di CSV (ke-{save_counter}) dan Simulasi Dihentikan oleh Coverage.")
                    else:
                         print(f"\n[INFO] Titik awal (lat={first_lat:.2f}, lon={first_lon:.2f}) masuk ke area spotbeam, tetapi batas CSV (5 data) sudah tercapai.")
                    
                    stop_simulation = True # Set flag untuk menghentikan animasi

    # Batasi jumlah titik lintasan (2 orbit)
    orbit_period_sec = 5520
    frame_sim_sec = (update_interval_ms/1000.0) * speedup
    max_points = int(2 * orbit_period_sec / frame_sim_sec)
    
    # 💾 PENYIMPANAN DATA PERIODE (Pengganti Mekanisme Lama)
    if len(track_lats) > max_points:
        # Jika belum dihentikan oleh kondisi coverage DAN belum mencapai batas baris
        if not stop_simulation and save_counter < max_saves:
            with open(csv_filename, "a", newline="") as f:
                writer = csv.writer(f)
                writer.writerow([
                    sim_time.strftime('%Y-%m-%d %H:%M:%S'),
                    f"{lat:.6f}", f"{lon:.6f}", f"{alt:.2f}", f"{last_area_km2:.2f}"
                ])
            save_counter += 1
            print(f"[INFO] Data spotbeam disimpan ke CSV (ke-{save_counter}) berdasarkan batas orbit.")
            
        # Logika membersihkan lintasan
        track_lats.pop(0)
        track_lons.pop(0)

    # Update teks
    area_text.set_text(f"Cakupan spotbeam: {last_area_km2/1e3:.2f} ribu km²")
    time_text.set_text(
        f"UTC sim: {sim_time.strftime('%Y-%m-%d %H:%M:%S')} | "
        f"lat={lat:.2f}, lon={lon:.2f}, alt={alt:.1f} km"
    )

    return (point_artist, line_artist, spotbeam_artist, time_text, area_text)

# Fungsi untuk menghentikan animasi Matplotlib (Wajib karena FuncAnimation tidak berhenti otomatis)
def check_stop():
    if stop_simulation:
        anim.event_source.stop()
        print("[INFO] Animasi Matplotlib Dihentikan.")
    else:
        fig.canvas.manager.window.after(100, check_stop)

anim = FuncAnimation(fig, update, interval=update_interval_ms, blit=True)

# Panggil pengecekan penghentian
if fig.canvas.manager:
    fig.canvas.manager.window.after(100, check_stop)

plt.show()
# Out:
# C:\Users\ADVAN\AppData\Local\Temp\ipykernel_17580\237285704.py:76: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start_real_time = datetime.utcnow().replace(tzinfo=timezone.utc)
# C:\Users\ADVAN\AppData\Local\Temp\ipykernel_17580\237285704.py:224: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   anim = FuncAnimation(fig, update, interval=update_interval_ms, blit=True)

# %% [markdown]
# FIX INSYAALLAH
#
# NOTE : GA LIMIT 5, TAPI MALAH INFITE DAN DATA NYA BNYK BAT ANJAYY
# GW RAGU DATA NYA BENER-BENER TIAP ORBIT
#
# kyk nya ada data overleap deh, karena parameter nya msh ambigu

# %%
import numpy as np
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib.animation import FuncAnimation
from skyfield.api import EarthSatellite, load, wgs84
from datetime import datetime, timedelta, timezone
from shapely.geometry import Polygon, Point
from shapely.ops import unary_union
from pyproj import Geod
import csv, os

# ---------- TLE ISS (ZARYA) ----------
tle_lines = [
    "EXPLORER 22",
    "1 00899U 64064A   25276.49600160  .00000579  00000-0  49569-3 0  9991",
    "2 00899  79.6909  47.8810 0120383 146.1380 214.7533 13.82947257 69497"
]
# -------------------------------------

update_interval_ms = 200     # ms per frame
speedup = 127                # percepatan waktu simulasi
spotbeam_width_km = 2000     # lebar strip coverage tegak lurus lintasan (km)

# Inisialisasi skyfield
ts = load.timescale()
sat = EarthSatellite(tle_lines[1], tle_lines[2], tle_lines[0], ts)

# Geod untuk hitung area di ellipsoid WGS84
geod = Geod(ellps="WGS84")

# === Variabel CSV & Kontrol Penghentian ===
csv_filename = "spotbeam_data.csv"
save_counter = 0 # Tetap digunakan untuk penomoran INFO
# max_saves = 5 <--- DIHAPUS
stop_simulation = False # Variabel kontrol penghentian utama

# buat file baru jika belum ada
if not os.path.exists(csv_filename):
    with open(csv_filename, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["UTC_time", "Latitude", "Longitude", "Altitude_km", "Spotbeam_Area_km2"])

def latlon_at_time(time_ts):
    geocentric = sat.at(time_ts)
    subpoint = wgs84.subpoint(geocentric)
    return subpoint.latitude.degrees, subpoint.longitude.degrees, subpoint.elevation.km

# Setup figure
fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_global()
ax.stock_img()
ax.coastlines(linewidth=0.6)

# Inisialisasi plot
line_artist, = ax.plot([], [], color='red', linewidth=2, label='Lintasan Satelit', transform=ccrs.Geodetic())
point_artist, = ax.plot([], [], 'bo', markersize=6, label='Satelit', transform=ccrs.Geodetic(), zorder=5)
spotbeam_artist, = ax.plot([], [], color='blue', alpha=0.3, transform=ccrs.Geodetic(), label="Spotbeam Strip")

time_text = ax.text(0.01, 0.03, '', transform=ax.transAxes, fontsize=9,
                    bbox=dict(facecolor='white', alpha=0.7))

area_text = ax.text(0.01, 0.08, '', transform=ax.transAxes, fontsize=9,
                    bbox=dict(facecolor='white', alpha=0.7))

plt.title('Animasi Satelit dengan Spotbeam Strip (Ground Track)')
plt.legend(loc='upper right')

# Variabel penyimpan lintasan
track_lats = []
track_lons = []

# Variabel kontrol crossing orbit
start_real_time = datetime.utcnow().replace(tzinfo=timezone.utc)
start_sim_time = start_real_time
first_lat, first_lon = None, None
start_point = None # Titik awal sebagai objek Shapely
last_cross_state = False
cross_tolerance = 5.0

# Variabel untuk luas area cakupan
spotbeam_union = None
last_area_km2 = 0.0

def update(frame):
    global track_lats, track_lons, first_lat, first_lon, start_point, last_cross_state
    global spotbeam_union, last_area_km2, save_counter, stop_simulation

    # 🛑 MEKANISME PENGHENTIAN: Hentikan proses jika bendera diaktifkan
    if stop_simulation:
        return (point_artist, line_artist, spotbeam_artist, time_text, area_text)

    elapsed_real = frame * (update_interval_ms / 1000.0)
    sim_seconds = elapsed_real * speedup
    sim_time = start_sim_time + timedelta(seconds=sim_seconds)
    t_ts = ts.utc(sim_time.year, sim_time.month, sim_time.day,
                  sim_time.hour, sim_time.minute, sim_time.second + sim_time.microsecond/1e6)

    lat, lon, alt = latlon_at_time(t_ts)

    # Normalisasi longitude ke -180..180
    if lon > 180:
        lon -= 360
    elif lon < -180:
        lon += 360

    # Simpan dan definisikan titik awal hanya sekali
    if first_lat is None and first_lon is None:
        first_lat, first_lon = lat, lon
        start_point = Point(first_lon, first_lat)

    # ... (Logika deteksi crossing dan pembersihan lintasan tetap sama) ...
    dist = np.sqrt((lat - first_lat)**2 + (lon - first_lon)**2)
    is_crossing = dist < cross_tolerance
    if is_crossing and not last_cross_state:
        # Logika pembersihan lintasan visual
        track_lats, track_lons = [], []
    last_cross_state = is_crossing

    # Tambahkan ke lintasan
    track_lats.append(lat)
    track_lons.append(lon)

    # Update titik & garis lintasan
    point_artist.set_data([lon], [lat])
    line_artist.set_data(track_lons, track_lats)

    # Hitung strip coverage
    if len(track_lats) > 1:
        lon_prev = track_lons[-2]
        lat_prev = track_lats[-2]
        dx, dy = lon - lon_prev, lat - lat_prev
        length = np.hypot(dx, dy)
        if length > 0:
            dx, dy = dx/length, dy/length
            nx, ny = -dy, dx
            half_w = (spotbeam_width_km / 111.0) / 2
            current_strip = Polygon([
                (lon_prev + nx*half_w, lat_prev + ny*half_w),
                (lon_prev - nx*half_w, lat_prev - ny*half_w),
                (lon      - nx*half_w, lat      - ny*half_w),
                (lon      + nx*half_w, lat      + ny*half_w)
            ])
            
            if spotbeam_union is None:
                spotbeam_union = current_strip
            else:
                # Akumulasi area cakupan
                spotbeam_union = unary_union([spotbeam_union, current_strip])
            
            x, y = current_strip.exterior.xy
            spotbeam_artist.set_data(x, y)

            if spotbeam_union.is_valid and not spotbeam_union.is_empty:
                polys = [spotbeam_union] if spotbeam_union.geom_type == "Polygon" else list(spotbeam_union.geoms)
                total_area_m2 = 0
                for poly in polys:
                    if len(poly.exterior.coords) >= 4:
                        poly_x, poly_y = poly.exterior.xy
                        area_m2, _ = geod.polygon_area_perimeter(poly_x, poly_y)
                        total_area_m2 += abs(area_m2)
                last_area_km2 = total_area_m2 / 1e6
                
                # 🎯 PENGHENTIAN UTAMA: Cek apakah titik awal sudah tercakup
                if start_point is not None and spotbeam_union.contains(start_point):
                    # Simpan baris terakhir sebelum berhenti
                    with open(csv_filename, "a", newline="") as f:
                        writer = csv.writer(f)
                        writer.writerow([
                            sim_time.strftime('%Y-%m-%d %H:%M:%S'),
                            f"{lat:.6f}", f"{lon:.6f}", f"{alt:.2f}", f"{last_area_km2:.2f}"
                        ])
                    save_counter += 1
                    print(f"\n[INFO] Titik awal (lat={first_lat:.2f}, lon={first_lon:.2f}) TERCATAT di CSV (ke-{save_counter}) dan Simulasi Dihentikan oleh Coverage.")
                    
                    stop_simulation = True # Set flag untuk menghentikan animasi
                    return (point_artist, line_artist, spotbeam_artist, time_text, area_text) # Keluar dari update

    # Batasi jumlah titik lintasan (2 orbit)
    orbit_period_sec = 5520
    frame_sim_sec = (update_interval_ms/1000.0) * speedup
    max_points = int(2 * orbit_period_sec / frame_sim_sec)
    
    # 💾 PENYIMPANAN DATA PERIODE (Berlanjut Tanpa Batas Maksimum Baris)
    if len(track_lats) > max_points:
        # Jika belum dihentikan oleh kondisi coverage, simpan data orbit penuh
        if not stop_simulation:
            with open(csv_filename, "a", newline="") as f:
                writer = csv.writer(f)
                writer.writerow([
                    sim_time.strftime('%Y-%m-%d %H:%M:%S'),
                    f"{lat:.6f}", f"{lon:.6f}", f"{alt:.2f}", f"{last_area_km2:.2f}"
                ])
            save_counter += 1
            print(f"[INFO] Data spotbeam disimpan ke CSV (ke-{save_counter}) berdasarkan batas orbit.")
            
        # Logika membersihkan lintasan
        track_lats.pop(0)
        track_lons.pop(0)

    # Update teks
    area_text.set_text(f"Cakupan spotbeam: {last_area_km2/1e3:.2f} ribu km²")
    time_text.set_text(
        f"UTC sim: {sim_time.strftime('%Y-%m-%d %H:%M:%S')} | "
        f"lat={lat:.2f}, lon={lon:.2f}, alt={alt:.1f} km"
    )

    return (point_artist, line_artist, spotbeam_artist, time_text, area_text)

# Fungsi untuk menghentikan animasi Matplotlib (Wajib karena FuncAnimation tidak berhenti otomatis)
def check_stop():
    if stop_simulation:
        anim.event_source.stop()
        print("[INFO] Animasi Matplotlib Dihentikan.")
    else:
        fig.canvas.manager.window.after(100, check_stop)

anim = FuncAnimation(fig, update, interval=update_interval_ms, blit=True)

# Panggil pengecekan penghentian
if fig.canvas.manager:
    fig.canvas.manager.window.after(100, check_stop)

plt.show()
# Out:
# C:\Users\TEMANS\AppData\Local\Temp\ipykernel_7484\3812179567.py:220: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   anim = FuncAnimation(fig, update, interval=update_interval_ms, blit=True)
# [INFO] Data spotbeam disimpan ke CSV (ke-1) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-2) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-3) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-4) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-5) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-6) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-7) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-8) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-9) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-10) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-11) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-12) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-13) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-14) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-15) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-16) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-17) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-18) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-19) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-20) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-21) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-22) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-23) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-24) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-25) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-26) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-27) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-28) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-29) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-30) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-31) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-32) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-33) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-34) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-35) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-36) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-37) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-38) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-39) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-40) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-41) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-42) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-43) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-44) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-45) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-46) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-47) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-48) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-49) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-50) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-51) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-52) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-53) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-54) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-55) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-56) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-57) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-58) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-59) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-60) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-61) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-62) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-63) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-64) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-65) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-66) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-67) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-68) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-69) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-70) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-71) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-72) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-73) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-74) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-75) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-76) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-77) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-78) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-79) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-80) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-81) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-82) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-83) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-84) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-85) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-86) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-87) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-88) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-89) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-90) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-91) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-92) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-93) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-94) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-95) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-96) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-97) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-98) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-99) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-100) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-101) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-102) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-103) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-104) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-105) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-106) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-107) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-108) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-109) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-110) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-111) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-112) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-113) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-114) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-115) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-116) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-117) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-118) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-119) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-120) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-121) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-122) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-123) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-124) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-125) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-126) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-127) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-128) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-129) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-130) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-131) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-132) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-133) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-134) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-135) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-136) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-137) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-138) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-139) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-140) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-141) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-142) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-143) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-144) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-145) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-146) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-147) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-148) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-149) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-150) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-151) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-152) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-153) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-154) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-155) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-156) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-157) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-158) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-159) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-160) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-161) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-162) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-163) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-164) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-165) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-166) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-167) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-168) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-169) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-170) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-171) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-172) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-173) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-174) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-175) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-176) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-177) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-178) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-179) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-180) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-181) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-182) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-183) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-184) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-185) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-186) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-187) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-188) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-189) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-190) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-191) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-192) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-193) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-194) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-195) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-196) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-197) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-198) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-199) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-200) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-201) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-202) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-203) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-204) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-205) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-206) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-207) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-208) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-209) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-210) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-211) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-212) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-213) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-214) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-215) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-216) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-217) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-218) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-219) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-220) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-221) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-222) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-223) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-224) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-225) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-226) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-227) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-228) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-229) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-230) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-231) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-232) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-233) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-234) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-235) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-236) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-237) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-238) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-239) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-240) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-241) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-242) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-243) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-244) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-245) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-246) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-247) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-248) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-249) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-250) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-251) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-252) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-253) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-254) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-255) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-256) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-257) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-258) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-259) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-260) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-261) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-262) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-263) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-264) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-265) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-266) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-267) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-268) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-269) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-270) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-271) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-272) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-273) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-274) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-275) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-276) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-277) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-278) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-279) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-280) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-281) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-282) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-283) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-284) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-285) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-286) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-287) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-288) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-289) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-290) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-291) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-292) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-293) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-294) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-295) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-296) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-297) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-298) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-299) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-300) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-301) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-302) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-303) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-304) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-305) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-306) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-307) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-308) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-309) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-310) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-311) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-312) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-313) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-314) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-315) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-316) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-317) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-318) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-319) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-320) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-321) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-322) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-323) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-324) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-325) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-326) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-327) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-328) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-329) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-330) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-331) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-332) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-333) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-334) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-335) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-336) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-337) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-338) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-339) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-340) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-341) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-342) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-343) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-344) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-345) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-346) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-347) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-348) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-349) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-350) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-351) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-352) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-353) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-354) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-355) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-356) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-357) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-358) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-359) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-360) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-361) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-362) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-363) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-364) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-365) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-366) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-367) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-368) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-369) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-370) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-371) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-372) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-373) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-374) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-375) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-376) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-377) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-378) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-379) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-380) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-381) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-382) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-383) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-384) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-385) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-386) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-387) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-388) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-389) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-390) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-391) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-392) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-393) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-394) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-395) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-396) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-397) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-398) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-399) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-400) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-401) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-402) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-403) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-404) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-405) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-406) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-407) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-408) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-409) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-410) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-411) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-412) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-413) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-414) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-415) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-416) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-417) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-418) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-419) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-420) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-421) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-422) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-423) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-424) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-425) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-426) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-427) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-428) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-429) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-430) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-431) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-432) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-433) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-434) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-435) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-436) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-437) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-438) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-439) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-440) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-441) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-442) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-443) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-444) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-445) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-446) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-447) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-448) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-449) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-450) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-451) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-452) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-453) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-454) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-455) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-456) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-457) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-458) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-459) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-460) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-461) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-462) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-463) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-464) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-465) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-466) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-467) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-468) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-469) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-470) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-471) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-472) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-473) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-474) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-475) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-476) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-477) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-478) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-479) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-480) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-481) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-482) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-483) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-484) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-485) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-486) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-487) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-488) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-489) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-490) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-491) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-492) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-493) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-494) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-495) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-496) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-497) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-498) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-499) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-500) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-501) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-502) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-503) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-504) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-505) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-506) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-507) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-508) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-509) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-510) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-511) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-512) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-513) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-514) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-515) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-516) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-517) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-518) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-519) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-520) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-521) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-522) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-523) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-524) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-525) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-526) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-527) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-528) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-529) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-530) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-531) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-532) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-533) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-534) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-535) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-536) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-537) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-538) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-539) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-540) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-541) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-542) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-543) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-544) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-545) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-546) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-547) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-548) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-549) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-550) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-551) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-552) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-553) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-554) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-555) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-556) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-557) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-558) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-559) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-560) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-561) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-562) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-563) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-564) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-565) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-566) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-567) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-568) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-569) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-570) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-571) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-572) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-573) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-574) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-575) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-576) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-577) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-578) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-579) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-580) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-581) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-582) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-583) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-584) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-585) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-586) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-587) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-588) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-589) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-590) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-591) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-592) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-593) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-594) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-595) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-596) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-597) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-598) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-599) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-600) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-601) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-602) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-603) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-604) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-605) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-606) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-607) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-608) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-609) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-610) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-611) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-612) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-613) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-614) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-615) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-616) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-617) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-618) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-619) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-620) berdasarkan batas orbit.
# [INFO] Data spotbeam disimpan ke CSV (ke-621) berdasarkan batas orbit.

# %%
import numpy as np
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib.animation import FuncAnimation
from skyfield.api import EarthSatellite, load, wgs84
from datetime import datetime, timedelta, timezone
from shapely.geometry import Polygon
from shapely.ops import unary_union
from pyproj import Geod
import csv, os

# ---------- TLE ISS (ZARYA) ----------
tle_lines = [
    "ISS (ZARYA)",
    "1 09022U 76069A   25276.66381223  .00000555  00000-0  19691-3 0  9998",
    "2 09022  74.0437  52.3216 0013176 202.6488 157.4086 14.36709130575537"
]
# -------------------------------------

update_interval_ms = 200
speedup = 127
spotbeam_width_km = 2000

# Inisialisasi skyfield
ts = load.timescale()
sat = EarthSatellite(tle_lines[1], tle_lines[2], tle_lines[0], ts)

# Ambil epoch pertama dari TLE
epoch_datetime = sat.epoch.utc_datetime().replace(tzinfo=timezone.utc)
print("[INFO] Epoch TLE:", epoch_datetime)

# Geod untuk hitung area
geod = Geod(ellps="WGS84")

# === Variabel CSV ===
csv_filename = "spotbeam_data.csv"
save_enabled = 0   # akan jadi False setelah epoch tercapai

if not os.path.exists(csv_filename):
    with open(csv_filename, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["UTC_time", "Latitude", "Longitude", "Altitude_km", "Spotbeam_Area_km2"])

def latlon_at_time(time_ts):
    geocentric = sat.at(time_ts)
    subpoint = wgs84.subpoint(geocentric)
    return subpoint.latitude.degrees, subpoint.longitude.degrees, subpoint.elevation.km

# Setup figure
fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_global()
ax.stock_img()
ax.coastlines(linewidth=0.6)

line_artist, = ax.plot([], [], color='red', linewidth=2, label='Lintasan Satelit', transform=ccrs.Geodetic())
point_artist, = ax.plot([], [], 'bo', markersize=6, label='Satelit', transform=ccrs.Geodetic(), zorder=5)
spotbeam_artist, = ax.plot([], [], color='blue', alpha=0.3, transform=ccrs.Geodetic(), label="Spotbeam Strip")

time_text = ax.text(0.01, 0.03, '', transform=ax.transAxes, fontsize=9,
                    bbox=dict(facecolor='white', alpha=0.7))
area_text = ax.text(0.01, 0.08, '', transform=ax.transAxes, fontsize=9,
                    bbox=dict(facecolor='white', alpha=0.7))

plt.title('Animasi Satelit dengan Spotbeam Strip (Ground Track)')
plt.legend(loc='upper right')

track_lats, track_lons = [], []
start_real_time = datetime.utcnow().replace(tzinfo=timezone.utc)
start_sim_time = start_real_time
first_lat, first_lon = None, None
last_cross_state = False
cross_tolerance = 5.0

spotbeam_union = None
last_area_km2 = 0.0

def update(frame):
    global track_lats, track_lons, first_lat, first_lon, last_cross_state
    global spotbeam_union, last_area_km2, save_enabled

    elapsed_real = frame * (update_interval_ms / 1000.0)
    sim_seconds = elapsed_real * speedup
    sim_time = start_sim_time + timedelta(seconds=sim_seconds)
    t_ts = ts.utc(sim_time.year, sim_time.month, sim_time.day,
                  sim_time.hour, sim_time.minute, sim_time.second + sim_time.microsecond/1e6)

    lat, lon, alt = latlon_at_time(t_ts)
    if lon > 180: lon -= 360
    elif lon < -180: lon += 360

    if first_lat is None and first_lon is None:
        first_lat, first_lon = lat, lon

    dist = np.sqrt((lat - first_lat)**2 + (lon - first_lon)**2)
    is_crossing = dist < cross_tolerance
    if is_crossing and not last_cross_state:
        spotbeam_union = None
        track_lats, track_lons = [], []
        first_lat, first_lon = lat, lon
    last_cross_state = is_crossing

    track_lats.append(lat)
    track_lons.append(lon)

    point_artist.set_data([lon], [lat])
    line_artist.set_data(track_lons, track_lats)

    if len(track_lats) > 1:
        lon_prev, lat_prev = track_lons[-2], track_lats[-2]
        dx, dy = lon - lon_prev, lat - lat_prev
        length = np.hypot(dx, dy)
        if length > 0:
            dx, dy = dx/length, dy/length
            nx, ny = -dy, dx
            half_w = (spotbeam_width_km / 111.0) / 2
            rect = Polygon([
                (lon_prev + nx*half_w, lat_prev + ny*half_w),
                (lon_prev - nx*half_w, lat_prev - ny*half_w),
                (lon     - nx*half_w, lat     - ny*half_w),
                (lon     + nx*half_w, lat     + ny*half_w)
            ])
            if spotbeam_union is None:
                spotbeam_union = rect
            else:
                spotbeam_union = unary_union([spotbeam_union, rect])
            x, y = rect.exterior.xy
            spotbeam_artist.set_data(x, y)

            if spotbeam_union.is_valid and not spotbeam_union.is_empty:
                polys = [spotbeam_union] if spotbeam_union.geom_type == "Polygon" else list(spotbeam_union.geoms)
                total_area_m2 = 0
                for poly in polys:
                    poly_x, poly_y = poly.exterior.xy
                    area_m2, _ = geod.polygon_area_perimeter(poly_x, poly_y)
                    total_area_m2 += abs(area_m2)
                last_area_km2 = total_area_m2 / 1e6

    # Batasi jumlah titik lintasan (2 orbit)
    orbit_period_sec = 5520
    frame_sim_sec = (update_interval_ms/1000.0) * speedup
    max_points = int(2 * orbit_period_sec / frame_sim_sec)
    if len(track_lats) > max_points:
        track_lats.pop(0)
        track_lons.pop(0)

        # === Simpan ke CSV sampai epoch tercapai ===
        if sim_time < epoch_datetime:
            with open(csv_filename, "a", newline="") as f:
                writer = csv.writer(f)
                writer.writerow([
                    sim_time.strftime('%Y-%m-%d %H:%M:%S'),
                    f"{lat:.6f}", f"{lon:.6f}", f"{alt:.2f}", f"{last_area_km2:.2f}"
                ])
            save_enabled+= 1
            print(f"[INFO] Data spotbeam disimpan ke CSV @ {sim_time}")
        elif  sim_time >= epoch_datetime:
            print("[STOP] Penyimpanan CSV dihentikan (sampai epoch pertama)")

    area_text.set_text(f"Cakupan spotbeam: {last_area_km2/1e3:.2f} ribu km²")
    time_text.set_text(
        f"UTC sim: {sim_time.strftime('%Y-%m-%d %H:%M:%S')} | "
        f"lat={lat:.2f}, lon={lon:.2f}, alt={alt:.1f} km"
    )

    return (point_artist, line_artist, spotbeam_artist, time_text, area_text)

anim = FuncAnimation(fig, update, interval=update_interval_ms, blit=True)
plt.show()
# Out:
# [INFO] Epoch TLE: 2025-10-03 15:55:53.376648+00:00
# C:\Users\TEMANS\AppData\Local\Temp\ipykernel_12752\550698991.py:170: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   anim = FuncAnimation(fig, update, interval=update_interval_ms, blit=True)
# Traceback (most recent call last):
#   File "C:\Users\TEMANS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\cbook.py", line 298, in process
#     func(*args, **kwargs)
#   File "C:\Users\TEMANS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\animation.py", line 912, in _start
#     self._init_draw()
#   File "C:\Users\TEMANS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\animation.py", line 1747, in _init_draw
#     self._draw_frame(frame_data)
#   File "C:\Users\TEMANS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\animation.py", line 1766, in _draw_frame
#     self._drawn_artists = self._func(framedata, *self._args)
#   File "C:\Users\TEMANS\AppData\Local\Temp\ipykernel_12752\501399878.py", line 149, in update
#     if logging_active and save_counter < max_saves:
# NameError: name 'logging_active' is not defined
# Traceback (most recent call last):
#   File "C:\Users\TEMANS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\cbook.py", line 298, in process
#     func(*args, **kwargs)
#   File "C:\Users\TEMANS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\animation.py", line 922, in _stop
#     self._fig.canvas.mpl_disconnect(self._resize_id)
# AttributeError: 'FuncAnimation' object has no attribute '_resize_id'

# %%
import numpy as np
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from skyfield.api import EarthSatellite, load, wgs84
from datetime import datetime, timedelta, timezone
import csv
import os

# === Muat TLE ===
tle_lines = [
    "ISS (ZARYA)",
    "1 25544U 98067A   24300.51167824  .00010210  00000+0  19731-3 0  9994",
    "2 25544  51.6436  62.4935 0004316  94.5114  28.9810 15.50044754426033"
]

sat = EarthSatellite(tle_lines[1], tle_lines[2], tle_lines[0])
ts = load.timescale()

# === Epoch Awal dan Batas Akhir ===
start_time = datetime.now(timezone.utc)
end_time = start_time + timedelta(minutes=120)  # simulasi 2 jam

times = []
lats = []
lons = []

# === Simulasi Pergerakan Satelit ===
t = start_time
step = timedelta(seconds=10)  # setiap 10 detik

print(f"Epoch pertama satelit: {sat.epoch.utc_datetime()}")

while t <= end_time:
    time_ts = ts.utc(t.year, t.month, t.day, t.hour, t.minute, t.second)
    subpoint = sat.at(time_ts).subpoint()
    lat, lon = subpoint.latitude.degrees, subpoint.longitude.degrees

    times.append(t.isoformat())
    lats.append(lat)
    lons.append(lon)

    # Jika satelit menabrak epoch pertama, hentikan loop
    if abs((t - sat.epoch.utc_datetime()).total_seconds()) < 5:
        print(f"Berhenti di waktu {t} karena mendekati epoch pertama.")
        break

    t += step

print(f"Jumlah data yang dikumpulkan: {len(times)}")

# === Simpan ke CSV ===
if len(times) > 0:
    csv_path = os.path.join(os.getcwd(), "satellite_track.csv")
    with open(csv_path, mode='w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["time", "latitude", "longitude"])
        for i in range(len(times)):
            writer.writerow([times[i], lats[i], lons[i]])
    print(f"✅ Data tersimpan ke {csv_path}")
else:
    print("⚠️ Tidak ada data yang dikumpulkan — file tidak dibuat.")
# Out:
# Epoch pertama satelit: 2024-10-26 12:16:48.999908+00:00
# Jumlah data yang dikumpulkan: 721
# ✅ Data tersimpan ke c:\Users\TEMANS\Documents\Zoom\satellite_track.csv
